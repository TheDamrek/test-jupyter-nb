# %%
import pandas as pd
print("Tout est parfait, Anaconda fonctionne dans VS Code !")
# Out:
# Tout est parfait, Anaconda fonctionne dans VS Code !

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Petit test pour vérifier que tout fonctionne
data = np.random.randn(100)
df = pd.DataFrame(data, columns=['Valeurs'])
print("Statistiques d'Anaconda :")
print(df.describe())
# Out:
# Statistiques d'Anaconda :
#           Valeurs
# count  100.000000
# mean    -0.164959
# std      0.904142
# min     -2.086442
# 25%     -0.844629
# 50%     -0.226517
# 75%      0.490025
# max      1.985392
